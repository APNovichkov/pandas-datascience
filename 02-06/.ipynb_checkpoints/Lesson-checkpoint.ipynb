# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[df['Fare'] > 100]['Survived'].value_counts()
# Out:
# 1    39
# 0    14
# Name: Survived, dtype: int64

# %%
39/(39+14)
# Out:
# 0.7358490566037735

# %%
len(df[(df['Survived'] == 1) & (df['Fare'] > 100)])
# Out:
# 39

# %%
len(df[df['Fare'] > 100])
# Out:
# 53

# %%
39/53
# Out:
# 0.7358490566037735

# %%
df[df['Survived'] == 1]['Sex'].value_counts()
# Out:
# female    233
# male      109
# Name: Sex, dtype: int64

# %%
109 / (109+233)
# Out:
# 0.31871345029239767

# %%
df[(df['Age'] < 30) & (df['Age'] > 20)]['Pclass'].value_counts()
# Out:
# 3    118
# 2     53
# 1     34
# Name: Pclass, dtype: int64

# %%
34/(34+53+118)
# Out:
# 0.16585365853658537

# %%
df[(df['Sex'] == "female" & (df['']))]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-684004d00ebc> in <module>
# ----> 1 df[(df['Sex'] == "female" & (df['']))]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''

# %%
fare_list = df[(df['Sex'] == 'male') & (df['Age'] > 30) & (df['Survived'] == 0)]

# %%
len(fare_list[fare_list['Fare'] < 35]['Fare'])
# Out:
# 132

# %%
|
# Out:
#   File "<ipython-input-44-4b37ef281455>", line 1
#     |
#     ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv('tennis.txt', delimiter="\t", header=None, names=['Outlook', 'Temp', 'Humidity', 'Wind', 'Decision'])

# %%
df
# Out:
#      Outlook  Temp Humidity    Wind Decision
# 1      Sunny   Hot     High    Weak       No
# 2      Sunny   Hot     High  Strong       No
# 3   Overcast   Hot     High    Weak      Yes
# 4       Rain  Mild     High    Weak      Yes
# 5       Rain  Cool   Normal    Weak      Yes
# 6       Rain  Cool   Normal  Strong       No
# 7   Overcast  Cool   Normal  Strong      Yes
# 8      Sunny  Mild     High    Weak       No
# 9      Sunny  Cool   Normal    Weak      Yes
# 10      Rain  Mild   Normal    Weak      Yes
# 11     Sunny  Mild   Normal  Strong      Yes
# 12  Overcast  Mild     High  Strong      Yes
# 13  Overcast   Hot   Normal    Weak      Yes
# 14      Rain  Mild     High  Strong       No

# %%
s = df[df['Decision'] == 'Yes']['Wind'].value_counts()

# %%
for item in s.keys():
    print(item)
# Out:
# Weak
# Strong

# %%
6/9
# Out:
# 0.6666666666666666

# %%
df[df['Wind'] == 'Weak']['Decision'].value_counts().sum()
# Out:
# 8

# %%
6/8
# Out:
# 0.75

# %%
#Needs to return the chance of player playing given a certain condition
def func(df, c_column, c_value, d_column):
    s = df[df[c_column] == c_value][d_column].value_counts()
    num_yes = s['Yes']
    num_total = s['Yes'] + s['No']
    
    print(s)
    decisions = {}
    for item in s.keys():
        if item not in decisions:
            decisions[item] = 1
        else:
            decisions[item] += 1
            
#     return (num_yes/num_total) * 100
    return decisions 
    
out = func(df, 'Temp', 'Mild', 'Decision')
print("{}%".format(out))
# Out:
# Yes    4
# No     2
# Name: Decision, dtype: int64
# {'Yes': 1, 'No': 1}%

# %%
#Needs to return the chance of player playing given a certain condition
def func(df, c_column, c_value, d_column):
    s = df[df[c_column] == c_value][d_column].value_counts()

    out = {}
    for i in s.items():
        out[i[0]] = i[1]/s.sum()
    
    return out
    
out = func(df, 'Wind', 'Weak', 'Decision')
print("{}".format(out))
# Out:
# {'Yes': 0.75, 'No': 0.25}

# %%
def func(c_column, c_value, d_column):
    df1 = pd.DataFrame(c_column)
    df2 = pd.DataFrame(d_column)
    
    df = pd.concat([df1, df2], axis=1)

    s = df[df[df.columns.values[0]] == c_value][df.columns.values[1]].value_counts()

    

    return (num_yes/num_total) * 100
    
out = func(df['Wind'], 'Weak', df['Decision'])
print("{}%".format(out))
# Out:
# 75.0%

# %%
import scipy.stats
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from IPython import display
import seaborn as sns
import csv

# %%
df = pd.read_csv('startup.csv')

# %%
df.head()
# Out:
#               name category_list  funding_total_usd     status country_code  \
# 0           H2O.ai      Software          33.600000  operating          USA
# 1         One Inc.        Mobile           1.150050  operating          USA
# 2       1000 Corks      Software           0.040000  operating          USA
# 3  1000museums.com      Software           6.795451  operating          USA
# 4            Redox        Health           4.000000  operating          USA
#
#   state_code           city  funding_rounds  \
# 0         CA  Mountain View             4.0
# 1         CA  San Francisco             3.0
# 2         OR    Lake Oswego             1.0
# 3         MA          Lenox             9.0
# 4         WI        Madison             2.0
#
#                                            Investors  Number_of_Investors  \
# 0  Capital One:20000000|Nexus Venture Partners:33...                 11.0
# 1  Camp One Ventures:150000|CRV:1000050|General C...                 12.0
# 2                               Start-Up Chile:40000                  1.0
# 3  Alliance of Angels:1289879.0|Converge Venture ...                  7.0
# 4  .406 Ventures:3530000|DreamIt Ventures:470000|...                  6.0
#
#   Acquirer Acquirer_Category Acquirer_Country Acquirer_State Acquirer_City  \
# 0        -                 -                -              -             -
# 1        -                 -                -              -             -
# 2        -                 -                -              -             -
# 3        -                 -                -              -             -
# 4        -                 -                -              -             -
#
#   Acquired_Price Acquired Currency         county founded_at  \
# 0              -                 -    Santa Clara       2011
# 1              -                 -  San Francisco       2011
# 2              -                 -      Clackamas       2008
# 3              -                 -      Berkshire       2008
# 4              -                 -           Dane       2014
#
#              Coordinates
# 0  37.399364:-122.079517
# 1  37.727239:-123.032229
# 2  45.412305:-122.699154
# 3   42.361228:-73.286788
# 4   43.087806:-89.430121

# %%
len(df)
# Out:
# 13732

# %%
df = df.dropna()

# %%
len(df)
# Out:
# 13712

# %%
date_group = df.groupby('founded_at')['funding_total_usd'].value_counts().unstack()

# %%
for row in date_group.iterrows():
    print(row)
# Out:
# ('1-Jan', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1-Jan, Length: 5177, dtype: float64)
# ('18-Sep', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 18-Sep, Length: 5177, dtype: float64)
# ('19-Jul', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 19-Jul, Length: 5177, dtype: float64)
# ('1902', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1902, Length: 5177, dtype: float64)
# ('1906', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1906, Length: 5177, dtype: float64)
# ('1908', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1908, Length: 5177, dtype: float64)
# ('1909', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1909, Length: 5177, dtype: float64)
# ('1911', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1911, Length: 5177, dtype: float64)
# ('1912', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1912, Length: 5177, dtype: float64)
# ('1914', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1914, Length: 5177, dtype: float64)
# ('1917', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1917, Length: 5177, dtype: float64)
# ('1918', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1918, Length: 5177, dtype: float64)
# ('1919', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1919, Length: 5177, dtype: float64)
# ('1920', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1920, Length: 5177, dtype: float64)
# ('1923', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1923, Length: 5177, dtype: float64)
# ('1924', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1924, Length: 5177, dtype: float64)
# ('1925', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1925, Length: 5177, dtype: float64)
# ('1926', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1926, Length: 5177, dtype: float64)
# ('1928', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1928, Length: 5177, dtype: float64)
# ('1929', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1929, Length: 5177, dtype: float64)
# ('1930', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1930, Length: 5177, dtype: float64)
# ('1933', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1933, Length: 5177, dtype: float64)
# ('1939', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1939, Length: 5177, dtype: float64)
# ('1944', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1944, Length: 5177, dtype: float64)
# ('1945', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1945, Length: 5177, dtype: float64)
# ('1947', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1947, Length: 5177, dtype: float64)
# ('1949', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1949, Length: 5177, dtype: float64)
# ('1950', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1950, Length: 5177, dtype: float64)
# ('1951', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1951, Length: 5177, dtype: float64)
# ('1952', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1952, Length: 5177, dtype: float64)
# ('1953', funding_total_usd
# 0.0100        NaN
# 0.0110        NaN
# 0.0120        NaN
# 0.0125        NaN
# 0.0132        NaN
#              ...
# 4715.0000     NaN
# 5820.0000     NaN
# 8207.4500     NaN
# 17600.0000    1.0
# 30079.5030    NaN
# Name: 1953, Length: 5177, dtype: float64)
# ('1954', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1954, Length: 5177, dtype: float64)
# ('1956', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1956, Length: 5177, dtype: float64)
# ('1958', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1958, Length: 5177, dtype: float64)
# ('1961', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1961, Length: 5177, dtype: float64)
# ('1962', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1962, Length: 5177, dtype: float64)
# ('1963', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1963, Length: 5177, dtype: float64)
# ('1965', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1965, Length: 5177, dtype: float64)
# ('1966', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1966, Length: 5177, dtype: float64)
# ('1967', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1967, Length: 5177, dtype: float64)
# ('1968', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1968, Length: 5177, dtype: float64)
# ('1969', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1969, Length: 5177, dtype: float64)
# ('1970', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1970, Length: 5177, dtype: float64)
# ('1971', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1971, Length: 5177, dtype: float64)
# ('1972', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1972, Length: 5177, dtype: float64)
# ('1973', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1973, Length: 5177, dtype: float64)
# ('1974', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1974, Length: 5177, dtype: float64)
# ('1975', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1975, Length: 5177, dtype: float64)
# ('1976', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1976, Length: 5177, dtype: float64)
# ('1977', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1977, Length: 5177, dtype: float64)
# ('1978', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1978, Length: 5177, dtype: float64)
# ('1979', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1979, Length: 5177, dtype: float64)
# ('1980', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1980, Length: 5177, dtype: float64)
# ('1981', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1981, Length: 5177, dtype: float64)
# ('1982', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1982, Length: 5177, dtype: float64)
# ('1983', funding_total_usd
# 0.0100        NaN
# 0.0110        NaN
# 0.0120        NaN
# 0.0125        NaN
# 0.0132        NaN
#              ...
# 4715.0000     NaN
# 5820.0000     NaN
# 8207.4500     NaN
# 17600.0000    NaN
# 30079.5030    1.0
# Name: 1983, Length: 5177, dtype: float64)
# ('1984', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1984, Length: 5177, dtype: float64)
# ('1985', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1985, Length: 5177, dtype: float64)
# ('1986', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1986, Length: 5177, dtype: float64)
# ('1987', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1987, Length: 5177, dtype: float64)
# ('1988', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1988, Length: 5177, dtype: float64)
# ('1989', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1989, Length: 5177, dtype: float64)
# ('1990', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1990, Length: 5177, dtype: float64)
# ('1991', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1991, Length: 5177, dtype: float64)
# ('1992', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1992, Length: 5177, dtype: float64)
# ('1993', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1993, Length: 5177, dtype: float64)
# ('1994', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1994, Length: 5177, dtype: float64)
# ('1995', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1995, Length: 5177, dtype: float64)
# ('1996', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1996, Length: 5177, dtype: float64)
# ('1997', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1997, Length: 5177, dtype: float64)
# ('1998', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 1998, Length: 5177, dtype: float64)
# ('1999', funding_total_usd
# 0.0100        NaN
# 0.0110        NaN
# 0.0120        NaN
# 0.0125        NaN
# 0.0132        NaN
#              ...
# 4715.0000     1.0
# 5820.0000     NaN
# 8207.4500     NaN
# 17600.0000    NaN
# 30079.5030    NaN
# Name: 1999, Length: 5177, dtype: float64)
# ('2000', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 2000, Length: 5177, dtype: float64)
# ('2001', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 2001, Length: 5177, dtype: float64)
# ('2002', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 2002, Length: 5177, dtype: float64)
# ('2003', funding_total_usd
# 0.0100        NaN
# 0.0110        NaN
# 0.0120        NaN
# 0.0125        NaN
# 0.0132        NaN
#              ...
# 4715.0000     NaN
# 5820.0000     1.0
# 8207.4500     NaN
# 17600.0000    NaN
# 30079.5030    NaN
# Name: 2003, Length: 5177, dtype: float64)
# ('2004', funding_total_usd
# 0.0100        1.0
# 0.0110        NaN
# 0.0120        NaN
# 0.0125        NaN
# 0.0132        NaN
#              ...
# 4715.0000     NaN
# 5820.0000     NaN
# 8207.4500     NaN
# 17600.0000    NaN
# 30079.5030    NaN
# Name: 2004, Length: 5177, dtype: float64)
# ('2005', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 2005, Length: 5177, dtype: float64)
# ('2006', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 2006, Length: 5177, dtype: float64)
# ('2007', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 2007, Length: 5177, dtype: float64)
# ('2008', funding_total_usd
# 0.0100        1.0
# 0.0110        NaN
# 0.0120        NaN
# 0.0125        NaN
# 0.0132        NaN
#              ...
# 4715.0000     NaN
# 5820.0000     NaN
# 8207.4500     NaN
# 17600.0000    NaN
# 30079.5030    NaN
# Name: 2008, Length: 5177, dtype: float64)
# ('2009', funding_total_usd
# 0.0100        2.0
# 0.0110        NaN
# 0.0120        3.0
# 0.0125        NaN
# 0.0132        NaN
#              ...
# 4715.0000     NaN
# 5820.0000     NaN
# 8207.4500     1.0
# 17600.0000    NaN
# 30079.5030    NaN
# Name: 2009, Length: 5177, dtype: float64)
# ('2010', funding_total_usd
# 0.0100        NaN
# 0.0110        NaN
# 0.0120        3.0
# 0.0125        NaN
# 0.0132        NaN
#              ...
# 4715.0000     NaN
# 5820.0000     NaN
# 8207.4500     NaN
# 17600.0000    NaN
# 30079.5030    NaN
# Name: 2010, Length: 5177, dtype: float64)
# ('2011', funding_total_usd
# 0.0100        2.0
# 0.0110        1.0
# 0.0120        1.0
# 0.0125        NaN
# 0.0132        NaN
#              ...
# 4715.0000     NaN
# 5820.0000     NaN
# 8207.4500     NaN
# 17600.0000    NaN
# 30079.5030    NaN
# Name: 2011, Length: 5177, dtype: float64)
# ('2012', funding_total_usd
# 0.0100        7.0
# 0.0110        NaN
# 0.0120        NaN
# 0.0125        NaN
# 0.0132        1.0
#              ...
# 4715.0000     NaN
# 5820.0000     NaN
# 8207.4500     NaN
# 17600.0000    NaN
# 30079.5030    NaN
# Name: 2012, Length: 5177, dtype: float64)
# ('2013', funding_total_usd
# 0.0100        1.0
# 0.0110        NaN
# 0.0120        1.0
# 0.0125        1.0
# 0.0132        NaN
#              ...
# 4715.0000     NaN
# 5820.0000     NaN
# 8207.4500     NaN
# 17600.0000    NaN
# 30079.5030    NaN
# Name: 2013, Length: 5177, dtype: float64)
# ('2014', funding_total_usd
# 0.0100        4.0
# 0.0110        NaN
# 0.0120        NaN
# 0.0125        1.0
# 0.0132        NaN
#              ...
# 4715.0000     NaN
# 5820.0000     NaN
# 8207.4500     NaN
# 17600.0000    NaN
# 30079.5030    NaN
# Name: 2014, Length: 5177, dtype: float64)
# ('2015', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 2015, Length: 5177, dtype: float64)
# ('24-Aug', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 24-Aug, Length: 5177, dtype: float64)
# ('26-Feb', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 26-Feb, Length: 5177, dtype: float64)
# ('29-Apr', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: 29-Apr, Length: 5177, dtype: float64)
# ('Feb-31', funding_total_usd
# 0.0100       NaN
# 0.0110       NaN
# 0.0120       NaN
# 0.0125       NaN
# 0.0132       NaN
#               ..
# 4715.0000    NaN
# 5820.0000    NaN
# 8207.4500    NaN
# 17600.0000   NaN
# 30079.5030   NaN
# Name: Feb-31, Length: 5177, dtype: float64)

# %%
date_list = list(df['founded_at'].sort_values().unique())

# %%
sum_by_date = []

for date in date_list:
    sum_by_date.append(df[df['founded_at'] == date]['funding_total_usd'].sum())
    
sum_by_date
# Out:
# [987.853094,
#  250.0,
#  9.0,
#  20.0,
#  16.0,
#  16.5,
#  245.0,
#  19.33,
#  2.0,
#  18.0,
#  300.0,
#  0.157,
#  120.0,
#  2.5,
#  1.75,
#  81.35,
#  0.15432,
#  16.600216,
#  1000.0,
#  59.929933,
#  25.65,
#  0.150768,
#  7.5,
#  5.0,
#  7.4,
#  10.0,
#  2.0,
#  28.5,
#  6.0,
#  96.30000000000001,
#  17600.0,
#  331.0,
#  60.0,
#  19.6,
#  23.5,
#  6.0,
#  207.259114,
#  25.0,
#  10.0,
#  90.8,
#  4.67321,
#  38.65,
#  13.378196,
#  3591.0,
#  21.36,
#  57.0726,
#  52.0,
#  0.75,
#  506.2,
#  334.096,
#  97.41040000000001,
#  489.73600000000005,
#  1109.7,
#  203.2,
#  402.561365,
#  30826.27123,
#  969.485851,
#  1235.964973,
#  430.713798,
#  716.3299959999999,
#  296.064354,
#  1181.0722830000002,
#  792.1911379999999,
#  1247.632421,
#  1073.55674,
#  1374.605991,
#  2250.795642,
#  3907.8827180000003,
#  4378.504615,
#  7232.24658342,
#  9221.717702399,
#  21293.925880151,
#  15731.084839000001,
#  16978.641015884,
#  18256.383254,
#  23352.259765249997,
#  27726.36569675,
#  24054.835289000002,
#  27880.752675999996,
#  34298.53740258,
#  27645.401071570002,
#  33681.691192,
#  21523.016813984003,
#  24591.242369436,
#  19868.646866529,
#  15863.696440848998,
#  4790.459357878,
#  672.336355021,
#  5.5,
#  1.0,
#  26.72,
#  18.5]

# %%
plt.figure(figsize=(20, 10), frameon=False)
plt.xticks(rotation=90)
sns.scatterplot(x = list(df['founded_at'].sort_values().unique()), y = sum_by_date)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-151-b7938ee7b4be> in <module>
#       1 plt.figure(figsize=(20, 10), frameon=False)
#       2 plt.xticks(rotation=90)
# ----> 3 sns.scatterplot(x = list(df['founded_at']).sort_values().unique(), y = sum_by_date)
#
# AttributeError: 'list' object has no attribute 'sort_values'

# %%
sorted_by_date = df.sort_values(by="founded_at")

# %%
software_df = sorted_by_date[sorted_by_date['category_list'] == 'Software']

# %%
sns.scatterplot(x='founded_at', y='funding_total_usd', data=software_df)
