# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('titanic.csv')

# %%
sns.distplot(df['Age'].dropna(), hist=True, bins=16)

# %%
age_variance = df['Age'].std()
age_variance
# Out:
# 14.526497332334042

# %%
age_mean = df['Age'].mean()
age_mean
# Out:
# 29.69911764705882

# %%
_= sns.distplot(df['Age'], kde=True, bins=16)
# Out:
# /usr/local/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# /usr/local/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:444: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # will not work for two columns.
# /usr/local/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:444: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # will not work for two columns.

# %%
x = [4,2,5,3,2,5,6,3,4,2,4,2,4,2,4,2,4]

plt.boxplot(df['Age'].dropna())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x126ac4e90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x126b34910>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x126ac4110>],
#  'medians': [<matplotlib.lines.Line2D at 0x126b34450>],
#  'fliers': [<matplotlib.lines.Line2D at 0x126b3e8d0>],
#  'means': []}

# %%
clean_df = df[(df['Age'] > age_mean-age_variance*3) & (df['Age'] < age_mean+age_variance*3)]

# %%
len(df['Age'].dropna())
# Out:
# 714

# %%
len(clean_df)
# Out:
# 712

# %%
outliers = df[df['Age'] > age_mean-age_variance*3]

# %%
len(outliers)
# Out:
# 714

# %% [markdown]
# # Confidence levels

# %%
df = pd.read_csv('iris.csv')

# %%
df['Species'].value_counts()
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %%
setosa_sepal_length_std = df[df['Species'] == 'Iris-setosa']['SepalLengthCm'].std()
setosa_sepal_length_std
# Out:
# 0.35248968721345136

# %%
setosa_mean = df[df['Species'] == 'Iris-setosa']['SepalLengthCm'].mean()
setosa_mean
# Out:
# 5.006

# %%
def get_bounds_z(pop_mean, pop_std, sample_size, sig_level):
    delta = stats.norm.ppf(1 - sig_level/2)*(pop_std/np.sqrt(sample_size))
    
    lower = pop_mean - delta
    upper = pop_mean + delta
    
    return lower, upper

def get_bounds_t(pop_mean, sample_size, sig_level):
    t_score = scipy.stats.t.pff(1 - sig_level/2, len(data_sample) - 1)

# %%
print("Lower bound: {}\nUpper bound: {}".format(get_bounds(5.01, .3524, 50, .05)[0], get_bounds(5.01, .3524, 50, .05)[1]))
# Out:
# Lower bound: 4.912321498459835
# Upper bound: 5.107678501540165

# %%
sns.distplot(df['SepalLengthCm'].dropna(), hist=True, bins=16)

# %%
setosa = df[df['Species'] == 'Iris-versicolor']

# %%
mean = setosa['SepalLengthCm'].mean()

# %%
std = setosa['SepalLengthCm'].std()

# %%
len(setosa)
# Out:
# 50

# %%
clean_df = setosa[(setosa['SepalLengthCm'] > (mean-std*3)) & (setosa['SepalLengthCm'] < (mean+std*3))]

# %%
len(clean_df)
# Out:
# 50

# %%
sns.distplot(setosa['SepalLengthCm'].dropna(), hist=True, bins=16)
